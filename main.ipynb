# %% [markdown]
# # Анализируем данные

# %%
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
import seaborn as sns

# %%
p = Path("data/xlsx/")
for x in p.rglob("*"):
    df = pd.read_excel(x, index_col=0)
    sns.lineplot(x='dt', y=df.columns[-1], data=df)
    plt.title(x)
    plt.show()
    # print('-------------------------')
